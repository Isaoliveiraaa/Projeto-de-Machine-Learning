# %% [markdown]
# # Projeto de Machine Learning

# %%
import pandas as pd #Trabalhar com bases de dados
import numpy as np #Trabalhar com calculos matemáticos
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split

# %%
# Dados simulados

metros_quadrados = np.array([60, 80, 100, 120, 140, 160, 180, 200, 220, 240])
valor = np.array([100000, 1300000, 150000, 180000, 200000, 230000, 250000, 280000, 300000, 330000])

df = pd.DataFrame({
    "metros_quadrados": metros_quadrados, 
    "valor": valor
})

# %%
df
# Out:
#    metros_quadrados    valor
# 0                60   100000
# 1                80  1300000
# 2               100   150000
# 3               120   180000
# 4               140   200000
# 5               160   230000
# 6               180   250000
# 7               200   280000
# 8               220   300000
# 9               240   330000

# %%
# Eixos do gráfico

x = df[['metros_quadrados']] #caracteristica (dados de entrada)
y = df['valor'] #rotulo (dados de saida)

# %%
# Conjunto de testes e treino

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#    metros_quadrados
# 8               220
# 1                80

# %%
y_pred = regressor.predict(x_test)

# %%
y_pred
# Out:
# array([304310.34482759, 125689.65517241])

# %%
# Exemplo de previsão valor de uma casa com 130 metros metros_quadrados

metros_quadrados_previsao = np.array([[130]])

# %%
valor_previsto = regressor.predict(metros_quadrados_previsao)
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(valor_previsto)
# Out:
# [189482.75862069]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ec06f703-6878-490b-bf81-48f6858d58d5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
